# %%
# import dependencies
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
print(cities[0])
len(cities)
# Out:
# barrow
# 772

# %%
# create an empty list to hold the weather data
city_data = []

# print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters
record_count = 1
set_count = 1

# loop through all the cities in our list
for i, city in enumerate(cities):  
    
    # group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # create endpoint url with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # log the URL, record and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_response = requests.get(city_url)
        if city_response.status_code != 200:
            print(f"City not found with {city_response.status_code} for url")
            continue
                         
        city_weather = city_response.json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except Exception as err:
        print(f"unexpected error {type(err)} {err} found for url")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | vista hermosa
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | samusu
# City not found with 404 for url
# Processing Record 6 of Set 1 | vestmannaeyjar
# Processing Record 7 of Set 1 | suriapet
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | whyalla
# Processing Record 10 of Set 1 | maniitsoq
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | lao cai
# Processing Record 15 of Set 1 | san juan
# Processing Record 16 of Set 1 | dudinka
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | seoul
# Processing Record 21 of Set 1 | brigham city
# Processing Record 22 of Set 1 | coihaique
# Processing Record 23 of Set 1 | kumluca
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | khatanga
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | kapoeta
# Processing Record 30 of Set 1 | felipe carrillo puerto
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | ashcroft
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | ituni
# City not found with 404 for url
# Processing Record 37 of Set 1 | belaya gora
# Processing Record 38 of Set 1 | abonnema
# Processing Record 39 of Set 1 | zafra
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | xuddur
# Processing Record 42 of Set 1 | balkanabat
# Processing Record 43 of Set 1 | new norfolk
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | gopinathpur
# Processing Record 46 of Set 1 | canavieiras
# Processing Record 47 of Set 1 | viedma
# Processing Record 48 of Set 1 | balingasay
# Processing Record 49 of Set 1 | cabo san lucas
# Processing Record 50 of Set 1 | porto nacional
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | sawakin
# Processing Record 3 of Set 2 | sobolevo
# Processing Record 4 of Set 2 | inuvik
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | lavrentiya
# Processing Record 7 of Set 2 | nguiu
# City not found with 404 for url
# Processing Record 8 of Set 2 | longyearbyen
# Processing Record 9 of Set 2 | shahrud
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | souillac
# Processing Record 12 of Set 2 | adrar
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | pestravka
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | muroto
# Processing Record 18 of Set 2 | bundaberg
# Processing Record 19 of Set 2 | acapulco
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | san luis
# Processing Record 22 of Set 2 | neuquen
# Processing Record 23 of Set 2 | nemuro
# Processing Record 24 of Set 2 | saskylakh
# Processing Record 25 of Set 2 | hirara
# Processing Record 26 of Set 2 | pauini
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | rawannawi
# City not found with 404 for url
# Processing Record 29 of Set 2 | rio grande
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | awbari
# Processing Record 34 of Set 2 | russkaya polyana
# Processing Record 35 of Set 2 | torbay
# Processing Record 36 of Set 2 | manta
# Processing Record 37 of Set 2 | amnat charoen
# Processing Record 38 of Set 2 | polyarnyy
# Processing Record 39 of Set 2 | alice springs
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | talnakh
# Processing Record 42 of Set 2 | bud
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | whitehorse
# Processing Record 45 of Set 2 | klaksvik
# Processing Record 46 of Set 2 | grindavik
# Processing Record 47 of Set 2 | znamenskoye
# Processing Record 48 of Set 2 | bontang
# Processing Record 49 of Set 2 | boa vista
# Processing Record 50 of Set 2 | luena
# Processing Record 1 of Set 3 | strezhevoy
# Processing Record 2 of Set 3 | narsaq
# Processing Record 3 of Set 3 | yellowknife
# Processing Record 4 of Set 3 | vaitupu
# City not found with 404 for url
# Processing Record 5 of Set 3 | faanui
# Processing Record 6 of Set 3 | chiknayakanhalli
# Processing Record 7 of Set 3 | dali
# Processing Record 8 of Set 3 | lasem
# Processing Record 9 of Set 3 | revda
# Processing Record 10 of Set 3 | ilulissat
# Processing Record 11 of Set 3 | attawapiskat
# City not found with 404 for url
# Processing Record 12 of Set 3 | taltal
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | lethem
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | saldanha
# Processing Record 20 of Set 3 | bethanien
# Processing Record 21 of Set 3 | mehamn
# Processing Record 22 of Set 3 | deming
# Processing Record 23 of Set 3 | esmeraldas
# Processing Record 24 of Set 3 | konotop
# Processing Record 25 of Set 3 | buala
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | temaraia
# City not found with 404 for url
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | xining
# Processing Record 30 of Set 3 | la barca
# Processing Record 31 of Set 3 | civitavecchia
# Processing Record 32 of Set 3 | tacuarembo
# Processing Record 33 of Set 3 | tidore
# City not found with 404 for url
# Processing Record 34 of Set 3 | coquimbo
# Processing Record 35 of Set 3 | nizhneyansk
# City not found with 404 for url
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | tual
# Processing Record 38 of Set 3 | guerrero negro
# Processing Record 39 of Set 3 | tiksi
# Processing Record 40 of Set 3 | taolanaro
# City not found with 404 for url
# Processing Record 41 of Set 3 | olafsvik
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | zhangye
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | tanshui
# City not found with 404 for url
# Processing Record 47 of Set 3 | sheridan
# Processing Record 48 of Set 3 | bonavista
# Processing Record 49 of Set 3 | jamestown
# Processing Record 50 of Set 3 | mezen
# Processing Record 1 of Set 4 | mwingi
# Processing Record 2 of Set 4 | kapuskasing
# Processing Record 3 of Set 4 | henties bay
# Processing Record 4 of Set 4 | aldama
# Processing Record 5 of Set 4 | yulara
# Processing Record 6 of Set 4 | te anau
# Processing Record 7 of Set 4 | araouane
# Processing Record 8 of Set 4 | dunedin
# Processing Record 9 of Set 4 | nikolskoye
# Processing Record 10 of Set 4 | fairbanks
# Processing Record 11 of Set 4 | sao joao da barra
# Processing Record 12 of Set 4 | lazaro cardenas
# Processing Record 13 of Set 4 | yuncheng
# Processing Record 14 of Set 4 | tomatlan
# Processing Record 15 of Set 4 | kruisfontein
# Processing Record 16 of Set 4 | sukhothai
# Processing Record 17 of Set 4 | la ronge
# Processing Record 18 of Set 4 | upata
# Processing Record 19 of Set 4 | marsa matruh
# Processing Record 20 of Set 4 | paamiut
# Processing Record 21 of Set 4 | general roca
# Processing Record 22 of Set 4 | maceio
# Processing Record 23 of Set 4 | thompson
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | barentsburg
# City not found with 404 for url
# Processing Record 26 of Set 4 | saleaula
# City not found with 404 for url
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | upernavik
# Processing Record 29 of Set 4 | meulaboh
# Processing Record 30 of Set 4 | tsihombe
# City not found with 404 for url
# Processing Record 31 of Set 4 | bathsheba
# Processing Record 32 of Set 4 | mundo nuevo
# Processing Record 33 of Set 4 | pine castle
# Processing Record 34 of Set 4 | medicine hat
# Processing Record 35 of Set 4 | najran
# Processing Record 36 of Set 4 | rio gallegos
# Processing Record 37 of Set 4 | namibe
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | khash
# Processing Record 40 of Set 4 | kaitangata
# Processing Record 41 of Set 4 | malkangiri
# Processing Record 42 of Set 4 | letlhakane
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | samarai
# Processing Record 46 of Set 4 | lebu
# Processing Record 47 of Set 4 | jizan
# Processing Record 48 of Set 4 | nizwa
# Processing Record 49 of Set 4 | ilam
# Processing Record 50 of Set 4 | puerto escondido
# Processing Record 1 of Set 5 | rovaniemi
# Processing Record 2 of Set 5 | shamary
# Processing Record 3 of Set 5 | lorengau
# Processing Record 4 of Set 5 | illoqqortoormiut
# City not found with 404 for url
# Processing Record 5 of Set 5 | tuni
# Processing Record 6 of Set 5 | anito
# Processing Record 7 of Set 5 | cap malheureux
# Processing Record 8 of Set 5 | luanda
# Processing Record 9 of Set 5 | freeport
# Processing Record 10 of Set 5 | port lavaca
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | oyama
# Processing Record 13 of Set 5 | karamea
# City not found with 404 for url
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | dhidhdhoo
# Processing Record 16 of Set 5 | zhovtneve
# Processing Record 17 of Set 5 | elban
# Processing Record 18 of Set 5 | georgetown
# Processing Record 19 of Set 5 | darnah
# Processing Record 20 of Set 5 | lata
# Processing Record 21 of Set 5 | mkushi
# Processing Record 22 of Set 5 | tautira
# Processing Record 23 of Set 5 | port hardy
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | dryden
# Processing Record 26 of Set 5 | guarapari
# Processing Record 27 of Set 5 | yerbogachen
# Processing Record 28 of Set 5 | chase
# Processing Record 29 of Set 5 | maicao
# Processing Record 30 of Set 5 | srivardhan
# Processing Record 31 of Set 5 | saint-georges
# Processing Record 32 of Set 5 | wattegama
# Processing Record 33 of Set 5 | launceston
# Processing Record 34 of Set 5 | champasak
# Processing Record 35 of Set 5 | swan hill
# Processing Record 36 of Set 5 | pyapon
# Processing Record 37 of Set 5 | amderma
# City not found with 404 for url
# Processing Record 38 of Set 5 | belle fourche
# Processing Record 39 of Set 5 | tumannyy
# City not found with 404 for url
# Processing Record 40 of Set 5 | port elizabeth
# Processing Record 41 of Set 5 | solnechnyy
# Processing Record 42 of Set 5 | oriximina
# Processing Record 43 of Set 5 | ridgecrest
# Processing Record 44 of Set 5 | lolua
# City not found with 404 for url
# Processing Record 45 of Set 5 | yunhe
# Processing Record 46 of Set 5 | phan rang
# City not found with 404 for url
# Processing Record 47 of Set 5 | shimoda
# Processing Record 48 of Set 5 | chokurdakh
# Processing Record 49 of Set 5 | ketchikan
# Processing Record 50 of Set 5 | beloha
# Processing Record 1 of Set 6 | asau
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | masuguru
# Processing Record 5 of Set 6 | belushya guba
# City not found with 404 for url
# Processing Record 6 of Set 6 | mayor pablo lagerenza
# Processing Record 7 of Set 6 | mnogovershinnyy
# Processing Record 8 of Set 6 | abu jubayhah
# City not found with 404 for url
# Processing Record 9 of Set 6 | manggar
# Processing Record 10 of Set 6 | kuruman
# Processing Record 11 of Set 6 | kerema
# Processing Record 12 of Set 6 | grand river south east
# City not found with 404 for url
# Processing Record 13 of Set 6 | dongsheng
# Processing Record 14 of Set 6 | eskisehir
# Processing Record 15 of Set 6 | nanortalik
# Processing Record 16 of Set 6 | ponta delgada
# Processing Record 17 of Set 6 | pangnirtung
# Processing Record 18 of Set 6 | malindi
# Processing Record 19 of Set 6 | lompoc
# Processing Record 20 of Set 6 | makat
# Processing Record 21 of Set 6 | chitral
# Processing Record 22 of Set 6 | yarmolyntsi
# Processing Record 23 of Set 6 | sentyabrskiy
# City not found with 404 for url
# Processing Record 24 of Set 6 | antalaha
# Processing Record 25 of Set 6 | beyneu
# Processing Record 26 of Set 6 | iisalmi
# Processing Record 27 of Set 6 | sao gabriel da cachoeira
# Processing Record 28 of Set 6 | laguna
# Processing Record 29 of Set 6 | sakakah
# Processing Record 30 of Set 6 | college
# Processing Record 31 of Set 6 | tommot
# Processing Record 32 of Set 6 | imeni poliny osipenko
# Processing Record 33 of Set 6 | juegang
# Processing Record 34 of Set 6 | tukrah
# Processing Record 35 of Set 6 | cedar city
# Processing Record 36 of Set 6 | korla
# Processing Record 37 of Set 6 | kavieng
# Processing Record 38 of Set 6 | naze
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | tazovskiy
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | show low
# Processing Record 43 of Set 6 | urumqi
# Processing Record 44 of Set 6 | xichang
# Processing Record 45 of Set 6 | hervey bay
# Processing Record 46 of Set 6 | yankton
# Processing Record 47 of Set 6 | erzin
# Processing Record 48 of Set 6 | patti
# Processing Record 49 of Set 6 | ambodifototra
# City not found with 404 for url
# Processing Record 50 of Set 6 | kizilskoye
# Processing Record 1 of Set 7 | mbaiki
# Processing Record 2 of Set 7 | riyadh
# Processing Record 3 of Set 7 | arona
# Processing Record 4 of Set 7 | bischofswerda
# Processing Record 5 of Set 7 | jingdezhen
# Processing Record 6 of Set 7 | saint-joseph
# Processing Record 7 of Set 7 | berlevag
# Processing Record 8 of Set 7 | opuwo
# Processing Record 9 of Set 7 | usinsk
# Processing Record 10 of Set 7 | abu samrah
# Processing Record 11 of Set 7 | vanavara
# Processing Record 12 of Set 7 | tura
# Processing Record 13 of Set 7 | hambantota
# Processing Record 14 of Set 7 | aneho
# Processing Record 15 of Set 7 | kutum
# Processing Record 16 of Set 7 | paita
# Processing Record 17 of Set 7 | loubomo
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | lima
# Processing Record 20 of Set 7 | mapastepec
# Processing Record 21 of Set 7 | majene
# Processing Record 22 of Set 7 | jumla
# Processing Record 23 of Set 7 | vila franca do campo
# Processing Record 24 of Set 7 | airai
# Processing Record 25 of Set 7 | clyde river
# Processing Record 26 of Set 7 | mys shmidta
# City not found with 404 for url
# Processing Record 27 of Set 7 | sibolga
# Processing Record 28 of Set 7 | chernyshevskiy
# Processing Record 29 of Set 7 | tigil
# Processing Record 30 of Set 7 | paradwip
# City not found with 404 for url
# Processing Record 31 of Set 7 | dire
# Processing Record 32 of Set 7 | yuzhou
# Processing Record 33 of Set 7 | sillamae
# Processing Record 34 of Set 7 | george town
# Processing Record 35 of Set 7 | sabratah
# Processing Record 36 of Set 7 | richards bay
# Processing Record 37 of Set 7 | teguldet
# Processing Record 38 of Set 7 | saint-francois
# Processing Record 39 of Set 7 | sur
# Processing Record 40 of Set 7 | louisbourg
# City not found with 404 for url
# Processing Record 41 of Set 7 | westport
# Processing Record 42 of Set 7 | huarmey
# Processing Record 43 of Set 7 | coxim
# Processing Record 44 of Set 7 | tiznit
# Processing Record 45 of Set 7 | jiaocheng
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | mecca
# Processing Record 48 of Set 7 | tocopilla
# Processing Record 49 of Set 7 | chuy
# Processing Record 50 of Set 7 | goulburn
# Processing Record 1 of Set 8 | rungata
# City not found with 404 for url
# Processing Record 2 of Set 8 | bridlington
# Processing Record 3 of Set 8 | aklavik
# Processing Record 4 of Set 8 | marzuq
# Processing Record 5 of Set 8 | sitka
# Processing Record 6 of Set 8 | qurbus
# Processing Record 7 of Set 8 | port hueneme
# Processing Record 8 of Set 8 | swellendam
# Processing Record 9 of Set 8 | samalaeulu
# City not found with 404 for url
# Processing Record 10 of Set 8 | pemberton
# Processing Record 11 of Set 8 | hof
# Processing Record 12 of Set 8 | payson
# Processing Record 13 of Set 8 | davila
# Processing Record 14 of Set 8 | sicuani
# Processing Record 15 of Set 8 | mutsamudu
# City not found with 404 for url
# Processing Record 16 of Set 8 | satitoa
# City not found with 404 for url
# Processing Record 17 of Set 8 | carlyle
# Processing Record 18 of Set 8 | rudnichnyy
# Processing Record 19 of Set 8 | zhigansk
# Processing Record 20 of Set 8 | mendeleyevo
# Processing Record 21 of Set 8 | tabiauea
# City not found with 404 for url
# Processing Record 22 of Set 8 | kupang
# Processing Record 23 of Set 8 | leningradskiy
# Processing Record 24 of Set 8 | namatanai
# Processing Record 25 of Set 8 | grand-lahou
# Processing Record 26 of Set 8 | redlands
# Processing Record 27 of Set 8 | abnub
# Processing Record 28 of Set 8 | vanimo
# Processing Record 29 of Set 8 | hihifo
# City not found with 404 for url
# Processing Record 30 of Set 8 | rocha
# Processing Record 31 of Set 8 | melfi
# Processing Record 32 of Set 8 | komsomolskiy
# Processing Record 33 of Set 8 | portland
# Processing Record 34 of Set 8 | ortona
# Processing Record 35 of Set 8 | severnyy
# Processing Record 36 of Set 8 | farah
# Processing Record 37 of Set 8 | rizhao
# Processing Record 38 of Set 8 | havelock
# Processing Record 39 of Set 8 | san cristobal
# Processing Record 40 of Set 8 | sidi ali
# Processing Record 41 of Set 8 | geraldton
# Processing Record 42 of Set 8 | nome
# Processing Record 43 of Set 8 | malkara
# Processing Record 44 of Set 8 | carutapera
# Processing Record 45 of Set 8 | sola
# Processing Record 46 of Set 8 | axim
# Processing Record 47 of Set 8 | sosnovo-ozerskoye
# Processing Record 48 of Set 8 | san patricio
# Processing Record 49 of Set 8 | guaruja
# Processing Record 50 of Set 8 | gold coast
# Processing Record 1 of Set 9 | melilla
# Processing Record 2 of Set 9 | jiroft
# City not found with 404 for url
# Processing Record 3 of Set 9 | artyom
# Processing Record 4 of Set 9 | batagay
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | rostaq
# City not found with 404 for url
# Processing Record 7 of Set 9 | chapais
# Processing Record 8 of Set 9 | otradnoye
# Processing Record 9 of Set 9 | perevoz
# Processing Record 10 of Set 9 | susurluk
# Processing Record 11 of Set 9 | athabasca
# Processing Record 12 of Set 9 | colares
# Processing Record 13 of Set 9 | severo-kurilsk
# Processing Record 14 of Set 9 | waipawa
# Processing Record 15 of Set 9 | labutta
# City not found with 404 for url
# Processing Record 16 of Set 9 | udachnyy
# Processing Record 17 of Set 9 | bonthe
# Processing Record 18 of Set 9 | iranshahr
# Processing Record 19 of Set 9 | altagracia de orituco
# Processing Record 20 of Set 9 | kirakira
# Processing Record 21 of Set 9 | iqaluit
# Processing Record 22 of Set 9 | altar
# Processing Record 23 of Set 9 | amlagora
# Processing Record 24 of Set 9 | genhe
# Processing Record 25 of Set 9 | bolungarvik
# City not found with 404 for url
# Processing Record 26 of Set 9 | dubai
# Processing Record 27 of Set 9 | bajil
# Processing Record 28 of Set 9 | madang
# Processing Record 29 of Set 9 | ye
# City not found with 404 for url
# Processing Record 30 of Set 9 | khovu-aksy
# Processing Record 31 of Set 9 | coalcoman
# City not found with 404 for url
# Processing Record 32 of Set 9 | biak
# Processing Record 33 of Set 9 | sistranda
# Processing Record 34 of Set 9 | kolpny
# Processing Record 35 of Set 9 | dong hoi
# Processing Record 36 of Set 9 | shawnee
# Processing Record 37 of Set 9 | butia
# Processing Record 38 of Set 9 | bereznehuvate
# Processing Record 39 of Set 9 | konstantinovka
# Processing Record 40 of Set 9 | bandarbeyla
# Processing Record 41 of Set 9 | talcahuano
# Processing Record 42 of Set 9 | labuhan
# Processing Record 43 of Set 9 | brae
# Processing Record 44 of Set 9 | ruatoria
# City not found with 404 for url
# Processing Record 45 of Set 9 | sri aman
# Processing Record 46 of Set 9 | arica
# Processing Record 47 of Set 9 | fort walton beach
# Processing Record 48 of Set 9 | santa cruz
# Processing Record 49 of Set 9 | burnie
# Processing Record 50 of Set 9 | santa vitoria do palmar
# Processing Record 1 of Set 10 | atyrau
# Processing Record 2 of Set 10 | palabuhanratu
# City not found with 404 for url
# Processing Record 3 of Set 10 | ternate
# Processing Record 4 of Set 10 | barra patuca
# Processing Record 5 of Set 10 | ano mera
# Processing Record 6 of Set 10 | loa janan
# Processing Record 7 of Set 10 | hammerfest
# Processing Record 8 of Set 10 | ribeira grande
# Processing Record 9 of Set 10 | el limon
# Processing Record 10 of Set 10 | turkistan
# Processing Record 11 of Set 10 | skeldon
# Processing Record 12 of Set 10 | guatire
# Processing Record 13 of Set 10 | qasigiannguit
# Processing Record 14 of Set 10 | concordia
# Processing Record 15 of Set 10 | sirsi
# Processing Record 16 of Set 10 | tuatapere
# Processing Record 17 of Set 10 | yarada
# Processing Record 18 of Set 10 | ozernovskiy
# Processing Record 19 of Set 10 | springdale
# Processing Record 20 of Set 10 | dharchula
# Processing Record 21 of Set 10 | casper
# Processing Record 22 of Set 10 | lensk
# Processing Record 23 of Set 10 | vila do maio
# Processing Record 24 of Set 10 | dien bien
# City not found with 404 for url
# Processing Record 25 of Set 10 | nuuk
# Processing Record 26 of Set 10 | warqla
# City not found with 404 for url
# Processing Record 27 of Set 10 | umzimvubu
# City not found with 404 for url
# Processing Record 28 of Set 10 | evensk
# Processing Record 29 of Set 10 | moura
# Processing Record 30 of Set 10 | hofn
# Processing Record 31 of Set 10 | san miguel
# Processing Record 32 of Set 10 | lagoa
# Processing Record 33 of Set 10 | mahon
# Processing Record 34 of Set 10 | novikovo
# Processing Record 35 of Set 10 | port augusta
# Processing Record 36 of Set 10 | vestmanna
# Processing Record 37 of Set 10 | jacareacanga
# Processing Record 38 of Set 10 | mandalgovi
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | xaghra
# Processing Record 41 of Set 10 | moron
# Processing Record 42 of Set 10 | san jeronimo
# Processing Record 43 of Set 10 | khani
# Processing Record 44 of Set 10 | mulatupo
# Processing Record 45 of Set 10 | stromness
# Processing Record 46 of Set 10 | nazret
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | poum
# Processing Record 49 of Set 10 | ugoofaaru
# Processing Record 50 of Set 10 | canutama
# Processing Record 1 of Set 11 | san policarpo
# Processing Record 2 of Set 11 | manono
# Processing Record 3 of Set 11 | touros
# Processing Record 4 of Set 11 | merauke
# Processing Record 5 of Set 11 | esperance
# Processing Record 6 of Set 11 | fort wellington
# Processing Record 7 of Set 11 | trinidad
# Processing Record 8 of Set 11 | san pedro
# Processing Record 9 of Set 11 | dwarka
# Processing Record 10 of Set 11 | temple
# Processing Record 11 of Set 11 | srednekolymsk
# Processing Record 12 of Set 11 | alpena
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | barawe
# City not found with 404 for url
# Processing Record 15 of Set 11 | nanchong
# Processing Record 16 of Set 11 | tambura
# Processing Record 17 of Set 11 | kalaleh
# Processing Record 18 of Set 11 | gazanjyk
# Processing Record 19 of Set 11 | santiago del estero
# Processing Record 20 of Set 11 | camacha
# Processing Record 21 of Set 11 | druzhba
# Processing Record 22 of Set 11 | fonte boa
# Processing Record 23 of Set 11 | ancud
# Processing Record 24 of Set 11 | ukiah
# Processing Record 25 of Set 11 | mahbubnagar
# Processing Record 26 of Set 11 | port lincoln
# Processing Record 27 of Set 11 | ola
# Processing Record 28 of Set 11 | narayanpet
# Processing Record 29 of Set 11 | ormara
# Processing Record 30 of Set 11 | eskasem
# City not found with 404 for url
# Processing Record 31 of Set 11 | north bend
# Processing Record 32 of Set 11 | atar
# Processing Record 33 of Set 11 | tamandare
# Processing Record 34 of Set 11 | guanica
# Processing Record 35 of Set 11 | port blair
# Processing Record 36 of Set 11 | mollendo
# Processing Record 37 of Set 11 | wajir
# Processing Record 38 of Set 11 | katsuura
# Processing Record 39 of Set 11 | sinnamary
# Processing Record 40 of Set 11 | malwan
# City not found with 404 for url
# Processing Record 41 of Set 11 | great falls
# Processing Record 42 of Set 11 | asfi
# Processing Record 43 of Set 11 | jacmel
# Processing Record 44 of Set 11 | samfya
# Processing Record 45 of Set 11 | tahe
# Processing Record 46 of Set 11 | muros
# Processing Record 47 of Set 11 | angra
# City not found with 404 for url
# Processing Record 48 of Set 11 | coahuayana
# Processing Record 49 of Set 11 | corrente
# Processing Record 50 of Set 11 | svetlogorsk
# Processing Record 1 of Set 12 | belousovka
# Processing Record 2 of Set 12 | grand-santi
# Processing Record 3 of Set 12 | hun
# Processing Record 4 of Set 12 | emerald
# Processing Record 5 of Set 12 | codrington
# Processing Record 6 of Set 12 | sragen
# Processing Record 7 of Set 12 | acutzilapan
# City not found with 404 for url
# Processing Record 8 of Set 12 | porto novo
# Processing Record 9 of Set 12 | redondo
# Processing Record 10 of Set 12 | llandrindod wells
# Processing Record 11 of Set 12 | natal
# Processing Record 12 of Set 12 | cockburn town
# Processing Record 13 of Set 12 | hualmay
# Processing Record 14 of Set 12 | yei
# Processing Record 15 of Set 12 | kiama
# Processing Record 16 of Set 12 | sampit
# Processing Record 17 of Set 12 | pacific grove
# Processing Record 18 of Set 12 | kathmandu
# Processing Record 19 of Set 12 | vila velha
# Processing Record 20 of Set 12 | tessalit
# Processing Record 21 of Set 12 | kochki
# Processing Record 22 of Set 12 | ewa beach
# Processing Record 23 of Set 12 | dzhusaly
# City not found with 404 for url
# Processing Record 24 of Set 12 | aripuana
# Processing Record 25 of Set 12 | stornoway
# Processing Record 26 of Set 12 | gambo
# Processing Record 27 of Set 12 | dingle
# Processing Record 28 of Set 12 | ryotsu
# Processing Record 29 of Set 12 | sao jose da coroa grande
# Processing Record 30 of Set 12 | mangla
# Processing Record 31 of Set 12 | margate
# Processing Record 32 of Set 12 | leh
# Processing Record 33 of Set 12 | razgrad
# Processing Record 34 of Set 12 | hecun
# Processing Record 35 of Set 12 | arman
# Processing Record 36 of Set 12 | yirol
# City not found with 404 for url
# Processing Record 37 of Set 12 | oskemen
# Processing Record 38 of Set 12 | mapiripan
# Processing Record 39 of Set 12 | mildura
# Processing Record 40 of Set 12 | ostrovnoy
# Processing Record 41 of Set 12 | ouro preto do oeste
# Processing Record 42 of Set 12 | qaqortoq
# Processing Record 43 of Set 12 | muravlenko
# Processing Record 44 of Set 12 | sandpoint
# Processing Record 45 of Set 12 | ingham
# Processing Record 46 of Set 12 | lisala
# Processing Record 47 of Set 12 | kurumkan
# Processing Record 48 of Set 12 | cascais
# Processing Record 49 of Set 12 | celestun
# Processing Record 50 of Set 12 | san quintin
# Processing Record 1 of Set 13 | ust-tsilma
# Processing Record 2 of Set 13 | haines junction
# Processing Record 3 of Set 13 | nouadhibou
# Processing Record 4 of Set 13 | nakhon si thammarat
# Processing Record 5 of Set 13 | erenhot
# Processing Record 6 of Set 13 | deputatskiy
# Processing Record 7 of Set 13 | zambezi
# Processing Record 8 of Set 13 | villa oliva
# City not found with 404 for url
# Processing Record 9 of Set 13 | saint-pierre
# Processing Record 10 of Set 13 | broome
# Processing Record 11 of Set 13 | abu road
# Processing Record 12 of Set 13 | shivrajpur
# Processing Record 13 of Set 13 | palmer
# Processing Record 14 of Set 13 | karaul
# City not found with 404 for url
# Processing Record 15 of Set 13 | iquique
# Processing Record 16 of Set 13 | daniel flores
# Processing Record 17 of Set 13 | khorramabad
# Processing Record 18 of Set 13 | zwedru
# Processing Record 19 of Set 13 | sagar
# Processing Record 20 of Set 13 | kalmunai
# Processing Record 21 of Set 13 | kocerinovo
# City not found with 404 for url
# Processing Record 22 of Set 13 | linhares
# Processing Record 23 of Set 13 | krasnoselkup
# Processing Record 24 of Set 13 | clinton
# Processing Record 25 of Set 13 | terrace
# Processing Record 26 of Set 13 | shingu
# Processing Record 27 of Set 13 | cayenne
# Processing Record 28 of Set 13 | sirjan
# Processing Record 29 of Set 13 | tilichiki
# Processing Record 30 of Set 13 | karamken
# City not found with 404 for url
# Processing Record 31 of Set 13 | ampanihy
# Processing Record 32 of Set 13 | nishihara
# Processing Record 33 of Set 13 | marquette
# Processing Record 34 of Set 13 | lubartow
# Processing Record 35 of Set 13 | marsh harbour
# Processing Record 36 of Set 13 | mayo
# Processing Record 37 of Set 13 | barcelos
# Processing Record 38 of Set 13 | derby
# Processing Record 39 of Set 13 | jhabua
# Processing Record 40 of Set 13 | port moresby
# Processing Record 41 of Set 13 | dolores
# Processing Record 42 of Set 13 | fort-shevchenko
# Processing Record 43 of Set 13 | sambava
# Processing Record 44 of Set 13 | isangel
# Processing Record 45 of Set 13 | albi
# Processing Record 46 of Set 13 | novyy urgal
# Processing Record 47 of Set 13 | lake havasu city
# Processing Record 48 of Set 13 | wonthaggi
# Processing Record 49 of Set 13 | santiago
# Processing Record 50 of Set 13 | bilma
# Processing Record 1 of Set 14 | lichinga
# Processing Record 2 of Set 14 | kota bahru
# Processing Record 3 of Set 14 | huizen
# Processing Record 4 of Set 14 | hede
# Processing Record 5 of Set 14 | kajaani
# Processing Record 6 of Set 14 | dandong
# Processing Record 7 of Set 14 | sundargarh
# Processing Record 8 of Set 14 | chunskiy
# Processing Record 9 of Set 14 | maragogi
# Processing Record 10 of Set 14 | sorland
# Processing Record 11 of Set 14 | jiangyou
# Processing Record 12 of Set 14 | marcona
# City not found with 404 for url
# Processing Record 13 of Set 14 | half moon bay
# Processing Record 14 of Set 14 | sioux lookout
# Processing Record 15 of Set 14 | kahului
# Processing Record 16 of Set 14 | can
# Processing Record 17 of Set 14 | umm lajj
# Processing Record 18 of Set 14 | muriti
# Processing Record 19 of Set 14 | guajara-mirim
# City not found with 404 for url
# Processing Record 20 of Set 14 | yepifan
# Processing Record 21 of Set 14 | dauriya
# Processing Record 22 of Set 14 | sal rei
# Processing Record 23 of Set 14 | ochamchira
# Processing Record 24 of Set 14 | acajutla
# Processing Record 25 of Set 14 | el vigia
# Processing Record 26 of Set 14 | da nang
# Processing Record 27 of Set 14 | sao paulo de olivenca
# Processing Record 28 of Set 14 | yatou
# Processing Record 29 of Set 14 | hue
# Processing Record 30 of Set 14 | vardo
# Processing Record 31 of Set 14 | ippy
# Processing Record 32 of Set 14 | flin flon
# Processing Record 33 of Set 14 | fougamou
# Processing Record 34 of Set 14 | buraydah
# Processing Record 35 of Set 14 | ngukurr
# City not found with 404 for url
# Processing Record 36 of Set 14 | eydhafushi
# Processing Record 37 of Set 14 | hope
# Processing Record 38 of Set 14 | trairi
# Processing Record 39 of Set 14 | tecoanapa
# Processing Record 40 of Set 14 | cozumel
# Processing Record 41 of Set 14 | halalo
# City not found with 404 for url
# Processing Record 42 of Set 14 | floriano
# Processing Record 43 of Set 14 | zabinka
# City not found with 404 for url
# Processing Record 44 of Set 14 | burns lake
# Processing Record 45 of Set 14 | paracuru
# Processing Record 46 of Set 14 | havoysund
# Processing Record 47 of Set 14 | port-cartier
# Processing Record 48 of Set 14 | hobyo
# Processing Record 49 of Set 14 | gisborne
# Processing Record 50 of Set 14 | mabaruma
# Processing Record 1 of Set 15 | sandwick
# Processing Record 2 of Set 15 | rosetta
# Processing Record 3 of Set 15 | krasnokamensk
# Processing Record 4 of Set 15 | krasnogvardeyskoye
# Processing Record 5 of Set 15 | aksarka
# Processing Record 6 of Set 15 | husavik
# Processing Record 7 of Set 15 | ndele
# Processing Record 8 of Set 15 | sainte-rose
# Processing Record 9 of Set 15 | gerash
# Processing Record 10 of Set 15 | honningsvag
# Processing Record 11 of Set 15 | channel-port aux basques
# Processing Record 12 of Set 15 | los alamos
# Processing Record 13 of Set 15 | port keats
# Processing Record 14 of Set 15 | putina
# Processing Record 15 of Set 15 | kaabong
# Processing Record 16 of Set 15 | palana
# Processing Record 17 of Set 15 | vicuna
# Processing Record 18 of Set 15 | cap estate
# Processing Record 19 of Set 15 | am timan
# Processing Record 20 of Set 15 | comodoro rivadavia
# Processing Record 21 of Set 15 | kuala terengganu
# Processing Record 22 of Set 15 | batemans bay
# Processing Record 23 of Set 15 | surab
# Processing Record 24 of Set 15 | el fuerte
# Processing Record 25 of Set 15 | krasnyy yar
# Processing Record 26 of Set 15 | myitkyina
# Processing Record 27 of Set 15 | daru
# Processing Record 28 of Set 15 | murray bridge
# Processing Record 29 of Set 15 | porto torres
# Processing Record 30 of Set 15 | brus laguna
# Processing Record 31 of Set 15 | diksmuide
# Processing Record 32 of Set 15 | unguia
# Processing Record 33 of Set 15 | port shepstone
# Processing Record 34 of Set 15 | mattru
# Processing Record 35 of Set 15 | realeza
# Processing Record 36 of Set 15 | beisfjord
# Processing Record 37 of Set 15 | salta
# Processing Record 38 of Set 15 | killeen
# Processing Record 39 of Set 15 | tel aviv-yafo
# Processing Record 40 of Set 15 | santa ines
# Processing Record 41 of Set 15 | hassleholm
# Processing Record 42 of Set 15 | hamilton
# Processing Record 43 of Set 15 | lincoln
# Processing Record 44 of Set 15 | chikoy
# City not found with 404 for url
# Processing Record 45 of Set 15 | galesong
# Processing Record 46 of Set 15 | buin
# Processing Record 47 of Set 15 | ilo
# Processing Record 48 of Set 15 | nefteyugansk
# Processing Record 49 of Set 15 | vostok
# Processing Record 50 of Set 15 | norrkoping
# Processing Record 1 of Set 16 | buta
# Processing Record 2 of Set 16 | kemi
# Processing Record 3 of Set 16 | gat
# Processing Record 4 of Set 16 | pingzhuang
# Processing Record 5 of Set 16 | kandrian
# Processing Record 6 of Set 16 | bosaso
# Processing Record 7 of Set 16 | cumberland
# Processing Record 8 of Set 16 | massa marittima
# Processing Record 9 of Set 16 | yichun
# Processing Record 10 of Set 16 | alofi
# Processing Record 11 of Set 16 | matay
# Processing Record 12 of Set 16 | port-gentil
# Processing Record 13 of Set 16 | paramonga
# Processing Record 14 of Set 16 | aasiaat
# Processing Record 15 of Set 16 | douglas
# Processing Record 16 of Set 16 | ocos
# Processing Record 17 of Set 16 | luancheng
# Processing Record 18 of Set 16 | thetford mines
# Processing Record 19 of Set 16 | dumai
# Processing Record 20 of Set 16 | ushumun
# Processing Record 21 of Set 16 | palauig
# Processing Record 22 of Set 16 | charters towers
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# convert array of dictionaries to a dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0          Barrow  71.2906 -156.7887          few clouds     15.82        79
# 1   Vista Hermosa  19.5167  -99.2167    scattered clouds     76.55        33
# 2          Kodiak  57.7900 -152.4072           clear sky     42.31        49
# 3       Busselton -33.6500  115.3333    scattered clouds     46.04        80
# 4  Vestmannaeyjar  63.4427  -20.2734       broken clouds     43.68        69
# 5        Suriapet  17.1500   79.6167       broken clouds     70.75        68
# 6    Puerto Ayora  -0.7393  -90.3518     overcast clouds     75.16        91
# 7         Whyalla -33.0333  137.5833       broken clouds     60.69        94
# 8       Maniitsoq  65.4167  -52.9000     overcast clouds     30.43        53
# 9        Cidreira -30.1811  -50.2056           clear sky     74.61        61
#
#    Cloudiness  Wind Speed Country
# 0          20        8.05      US
# 1          40        8.05      MX
# 2           1        3.44      US
# 3          47        8.79      AU
# 4          55       12.24      IS
# 5          78        6.96      IN
# 6          90        8.01      EC
# 7          75       11.50      AU
# 8          92        7.29      GL
# 9           0        9.93      BR

# %%
# reorder df columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Barrow      US  71.2906 -156.7887     15.82        79          20
# 1   Vista Hermosa      MX  19.5167  -99.2167     76.55        33          40
# 2          Kodiak      US  57.7900 -152.4072     42.31        49           1
# 3       Busselton      AU -33.6500  115.3333     46.04        80          47
# 4  Vestmannaeyjar      IS  63.4427  -20.2734     43.68        69          55
# 5        Suriapet      IN  17.1500   79.6167     70.75        68          78
# 6    Puerto Ayora      EC  -0.7393  -90.3518     75.16        91          90
# 7         Whyalla      AU -33.0333  137.5833     60.69        94          75
# 8       Maniitsoq      GL  65.4167  -52.9000     30.43        53          92
# 9        Cidreira      BR -30.1811  -50.2056     74.61        61           0
#
#    Wind Speed Current Description
# 0        8.05          few clouds
# 1        8.05    scattered clouds
# 2        3.44           clear sky
# 3        8.79    scattered clouds
# 4       12.24       broken clouds
# 5        6.96       broken clouds
# 6        8.01     overcast clouds
# 7       11.50       broken clouds
# 8        7.29     overcast clouds
# 9        9.93           clear sky

# %%
# create output file (csv)
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# export the city data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
